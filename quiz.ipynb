# %%
import pandas as pd
pd_ = pd.read_csv("vaccination.csv")
data = pd_.copy()
data
# Out:
#         country        date  daily_vaccinations  \
# 0     Argentina  12/29/2020                 NaN
# 1     Argentina  12/30/2020             15656.0
# 2     Argentina  12/31/2020             15656.0
# 3     Argentina    1/1/2021             11070.0
# 4     Argentina    1/2/2021              8776.0
# ...         ...         ...                 ...
# 1497      Wales   1/20/2021             11105.0
# 1498      Wales   1/21/2021             12318.0
# 1499      Wales   1/22/2021             15148.0
# 1500      Wales   1/23/2021             17371.0
# 1501      Wales   1/24/2021             17063.0
#
#                                  vaccines
# 0                               Sputnik V
# 1                               Sputnik V
# 2                               Sputnik V
# 3                               Sputnik V
# 4                               Sputnik V
# ...                                   ...
# 1497  Oxford/AstraZeneca, Pfizer/BioNTech
# ...

# %%
    # boş hücreleri doldurmak için fonksiyon oluşturuyoruz
    def fill_empty_cells(row_idx, country):
        # ülkeye ait tarih ve aşının markasını buluyoruz
        date = data[row_idx][1]
        brand = data[row_idx][3]
        
        # ilkönce, "country" isimli ülkenin aşılama sayılarını buluyoruz
        country_data = [line for line in data if line[0] == country and line[2] != ""]
        # herhangi bir veri yoksa boş döndürüyoruz
        if not country_data:
            return ""
        
        # aşılama sayılarının bulunduğu sütunu buluyoruz
        column_idx = 2
        min_value = float(country_data[0][2])
        for i in range(1, len(country_data)):
            if country_data[i][2] != "" and float(country_data[i][2]) < min_value:
                column_idx = 2 + i
                min_value = float(country_data[i][2])
        
        # boş hücreyi dolduruyoruz ve sonucu döndürüyoruz
        data[row_idx][2] = str(min_value)
        return str(min_value)
    
    # boş hücreleri dolduruyoruz
    for i in range(len(data)):
        if data[i][2] == "":
            fill_empty_cells(i, data[i][0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
 # yeni csv dosyasını oluşturuyoruz
    new_data = [",".join(line) for line in data]
    with open("new_grafik.csv", "w") as nf:
        nf.write("\n".join(new_data))

# %%
for country in df['Ülke'].unique():
    min_val = df.loc[df['Ülke'] == country, 'Günlük Aşılama'].min()
    df.loc[(df['Günlük Aşılama'].isnull()) & (df['Ülke'] == country), 'Günlük Aşılama'] = min_val

#Ülke aşılama verisi yoksa 0 değerini yerleştirme:
df['Günlük Aşılama'] = df['Günlük Aşılama'].fillna(0)
